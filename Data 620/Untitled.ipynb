# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node("A", pos=(0,3))
G.add_node("B", pos=(0,1))
G.add_node("C", pos=(1,4))
G.add_node("D", pos=(1,2))
G.add_node("E", pos=(1,0))
G.add_node("F", pos=(2,3))
G.add_node("G", pos=(2,1))
G.add_node("H", pos=(3,2))
G.add_node("I", pos=(4,2))
G.add_node("J", pos=(5,2))
nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('A','B', weight=50,relation='friend')
G.add_edge('A','C', weight=50,relation='friend')
G.add_edge('A','F', weight=50,relation='friend')
G.add_edge('A','D', weight=50,relation='friend')

# %%
G.add_edge('B','G', weight=50,relation='friend')
G.add_edge('B','A', weight=50,relation='friend')
G.add_edge('B','D', weight=50,relation='friend')
G.add_edge('B','E', weight=50,relation='friend')
nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('C','D', weight=50,relation='friend')
G.add_edge('C','F', weight=50,relation='friend')
G.add_edge('C','A', weight=50,relation='friend')

nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('D','A', weight=50,relation='friend')
G.add_edge('D','B', weight=50,relation='friend')
G.add_edge('D','C', weight=50,relation='friend')
G.add_edge('D','E', weight=50,relation='friend')
G.add_edge('D','F', weight=50,relation='friend')
G.add_edge('D','G', weight=50,relation='friend')


nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('E','B', weight=50,relation='friend')
G.add_edge('E','D', weight=50,relation='friend')
G.add_edge('E','G', weight=50,relation='friend')

nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('F','C', weight=50,relation='friend')
G.add_edge('F','A', weight=50,relation='friend')
G.add_edge('F','D', weight=50,relation='friend')
G.add_edge('F','G', weight=50,relation='friend')
G.add_edge('F','H', weight=50,relation='friend')


nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('G','E', weight=50,relation='friend')
G.add_edge('G','B', weight=50,relation='friend')
G.add_edge('G','D', weight=50,relation='friend')
G.add_edge('G','F', weight=50,relation='friend')
G.add_edge('G','H', weight=50,relation='friend')


nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('H','F', weight=50,relation='friend')
G.add_edge('H','G', weight=50,relation='friend')
G.add_edge('H','I', weight=50,relation='friend')

nx.draw_shell(G, with_labels=True)

# %%
G.add_edge('I','H', weight=50,relation='friend')
G.add_edge('I','J', weight=50,relation='friend')

nx.draw_shell(G, with_labels=True)
pos=nx.get_node_attributes(G,'pos')

# %%
nx.draw(G,pos, with_labels=True)
