# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\mians\\OneDrive\\Documents\\GitHub\\SPS-Work\\Data 620'

# %%
#nodes=pd.read_csv('https://github.com/mianshariq/SPS-Work/blob/1c7ab6c57d633d04155b502f5e867cfa0d3e74ab/Data%20620/SC_Nodes.csv')
edges=pd.read_csv('https://github.com/mianshariq/SPS-Work/raw/1c7ab6c57d633d04155b502f5e867cfa0d3e74ab/Data%20620/SC_edges.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-47-12fb2bd28f89> in <module>
#       1 #nodes=pd.read_csv('https://github.com/mianshariq/SPS-Work/blob/1c7ab6c57d633d04155b502f5e867cfa0d3e74ab/Data%20620/SC_Nodes.csv')
# ----> 2 edges=pd.read_csv('https://github.com/mianshariq/SPS-Work/raw/1c7ab6c57d633d04155b502f5e867cfa0d3e74ab/Data%20620/SC_edges.csv')
#
# ...

# %%
G=nx.from_pandas_edgelist(edges,'from', 'to')

# %%
nx.diameter(G)
# Out:
# 10

# %%
nx.center(G)
# Out:
# [10001, 10002, 10003, 10004, 10005, 10006, 10007, 10008, 50009, 50010]

# %%
nx.draw_shell(G)

# %%
pos=nx.spring_layout(G)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-42-5b9a2663af72> in <module>
# ----> 1 pos=nx.spring_layout(G)
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ...

# %%
for index, row in nodes.iterrows():
    node_label = row[1]
    position = (int(row['xPosition']), int(row['yPosition']))
    G.add_node(node_label, pos=position)

# %%
node_list

# %%
for pair in node_list:
    G.add_node(pair[0], pair[1])

# %%
for pair in edge_list:
    G.add_edge(pair[0], pair[1])
    
fig = plt.figure(figsize=(8, 6))
nx.draw_shell(G)
plt.show()

# %%
G=nx.Graph()

# %%
print(G.nodes()) # returns a list
print(G.edges()) # returns a list

# %%
nx.draw_shell(G)
plt.show()
